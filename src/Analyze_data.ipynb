# %% [markdown]
# # The Interplay of Compile-time Options and Run-time Options for Performance Prediction

# %% [markdown]
# #### Import libraries

# %%
import os

import pandas as pd

import numpy as np

from scipy import stats
import scipy.stats as sc
from scipy.cluster.hierarchy import linkage, leaves_list

import statsmodels.api as sm

from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor

import seaborn as sns

import matplotlib.pyplot as plt

# %% [markdown]
# ##### Variables to keep

# %%
data_dir = "../data/"

# %% [markdown]
# # x264

# %% [markdown]
# #### Variables to change

# %%
name_system = "x264"

# %%
list_dir = os.listdir(data_dir+name_system)
list_dir.remove('ctime_options.csv')
list_dir

inputs = os.listdir(data_dir+name_system+'/'+list_dir[0])
nb_inputs = len(inputs)

data = dict()

for i in range(len(list_dir)):
    for j in range(len(inputs)):
        loc = data_dir+name_system+'/'+list_dir[i]+'/'+inputs[j]
        data[list_dir[i], inputs[j]] = pd.read_csv(loc)

# %% [markdown]
# #### Few plots

# %% [markdown]
# ### Fps

# %%
dim = "fps"
for j in range(len(inputs)):
    plt.figure(figsize=(10,6))
    plt.title(inputs[j], size =20)
    plt.ylabel("Encoded fps (number of frames)", size=20)
    plt.xlabel("Configuration ids", size=20)
    plt.yticks(size=15)
    plt.xticks(size=15)
    for i in range(len(list_dir)):
        df = data[list_dir[i], inputs[j]]
        plt.scatter(range(df.shape[0]), df[dim])
    plt.savefig('../results/'+name_system+'/scatterplot_'+dim+'_'+inputs[j][:-4]+'.png')
    plt.show()

# %% [markdown]
# ### Bitrate

# %%
dim = "kbs"
for j in range(len(inputs)):
    plt.figure(figsize=(10,6))
    plt.title(inputs[j], size =20)
    plt.ylabel("Bitrate (kbs)", size=20)
    plt.xlabel("Configuration ids", size=20)
    plt.yticks(size=15)
    plt.xticks(size=15)
    for i in range(len(list_dir)):
        df = data[list_dir[i], inputs[j]]
        plt.scatter(range(df.shape[0]), df[dim])
    plt.savefig('../results/'+name_system+'/scatterplot_'+dim+'_'+inputs[j][:-4]+'.png')
    plt.show()

# %% [markdown]
# ### Size

# %%
dim = "size"
for j in range(len(inputs)):
    plt.figure(figsize=(10,6))
    plt.title(inputs[j], size =20)
    plt.ylabel("Size (bytes)", size=20)
    plt.xlabel("Configuration ids", size=20)
    plt.yticks(size=15)
    plt.xticks(size=15)
    for i in range(len(list_dir)):
        df = data[list_dir[i], inputs[j]]
        plt.scatter(range(df.shape[0]), df[dim])
    plt.savefig('../results/'+name_system+'/scatterplot_'+dim+'_'+inputs[j][:-4]+'.png')
    plt.show()

# %% [markdown]
# ### Time

# %%
dim = "time"
for j in range(len(inputs)):
    plt.figure(figsize=(10,6))
    plt.title(inputs[j], size =20)
    plt.ylabel("Time (seconds)", size=20)
    plt.xlabel("Configuration ids", size=20)
    plt.yticks(size=15)
    plt.xticks(size=15)
    for i in range(len(list_dir)):
        df = data[list_dir[i], inputs[j]]
        plt.scatter(range(df.shape[0]), df[dim])
    plt.savefig('../results/'+name_system+'/scatterplot_'+dim+'_'+inputs[j][:-4]+'.png')
    plt.show()

# %% [markdown]
# #### Aggregate the data

# %% [markdown]
# ### xz

# %%
name_system = "xz"

# %%
list_dir = os.listdir(data_dir+name_system)
list_dir.remove('ctime_options.csv')
list_dir

inputs = os.listdir(data_dir+name_system+'/'+list_dir[0])
nb_inputs = len(inputs)

data = dict()

for i in range(len(list_dir)):
    for j in range(len(inputs)):
        loc = data_dir+name_system+'/'+list_dir[i]+'/'+inputs[j]
        data[list_dir[i], inputs[j]] = pd.read_csv(loc)

# %%
dim = "size"
for j in range(len(inputs)):
    plt.figure(figsize=(10,6))
    plt.title(inputs[j], size =20)
    plt.ylabel("Size (compressed, in bytes)", size=20)
    plt.xlabel("Configuration ids", size=20)
    plt.yticks(size=15)
    plt.xticks(size=15)
    for i in range(len(list_dir)):
        df = data[list_dir[i], inputs[j]]
        plt.scatter(range(df.shape[0]), df[dim])
    plt.savefig('../results/'+name_system+'/scatterplot_'+dim+'_'+inputs[j][:-4]+'.png')
    plt.show()

# %%
dim = "time"
for j in range(len(inputs)):
    plt.figure(figsize=(10,6))
    plt.title(inputs[j], size =20)
    plt.ylabel("Time (seconds)", size=20)
    plt.xlabel("Configuration ids", size=20)
    plt.yticks(size=15)
    plt.xticks(size=15)
    for i in range(len(list_dir)):
        df = data[list_dir[i], inputs[j]]
        plt.scatter(range(df.shape[0]), df[dim])
    plt.savefig('../results/'+name_system+'/scatterplot_'+dim+'_'+inputs[j][:-4]+'.png')
    plt.show()

# %% [markdown]
# ### poppler

# %%
name_system = "poppler"

# %%
list_dir = os.listdir(data_dir+name_system)
list_dir.remove('ctime_options.csv')
list_dir

inputs = os.listdir(data_dir+name_system+'/'+list_dir[0])
nb_inputs = len(inputs)

data = dict()

for i in range(len(list_dir)):
    for j in range(len(inputs)):
        loc = data_dir+name_system+'/'+list_dir[i]+'/'+inputs[j]
        data[list_dir[i], inputs[j]] = pd.read_csv(loc)

# %%
dim = "size"
for j in range(len(inputs)):
    plt.figure(figsize=(10,6))
    plt.title(inputs[j], size =20)
    plt.ylabel("Size (compressed, in bytes)", size=20)
    plt.xlabel("Configuration ids", size=20)
    plt.yticks(size=15)
    plt.xticks(size=15)
    for i in range(len(list_dir)):
        df = data[list_dir[i], inputs[j]]
        plt.scatter(range(df.shape[0]), df[dim])
    plt.savefig('../results/'+name_system+'/scatterplot_'+dim+'_'+inputs[j][:-4]+'.png')
    plt.show()

# %%
dim = "time"
for j in range(len(inputs)):
    plt.figure(figsize=(10,6))
    plt.title(inputs[j], size =20)
    plt.ylabel("Time (seconds)", size=20)
    plt.xlabel("Configuration ids", size=20)
    plt.yticks(size=15)
    plt.xticks(size=15)
    for i in range(len(list_dir)):
        df = data[list_dir[i], inputs[j]]
        plt.scatter(range(df.shape[0]), df[dim])
    plt.savefig('../results/'+name_system+'/scatterplot_'+dim+'_'+inputs[j][:-4]+'.png')
    plt.show()
